# %%
# %load_ext sql
# %sql postgresql://postgres:123456@localhost/learn-fastapi
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ### Database Diagram
# <img src="../database_diagrams/v5_Ally_database_diagram.png" width="760px">

# %% [markdown]
# #### Get all the users

# %%
# %sql SELECT * FROM users AS u;
# Out:
#  * postgresql://postgres:***@localhost/learn-fastapi
# 1 rows affected.
# [('admin@admin.com', '$2b$12$hR0xP39SMN5ojClEf8PiE.BPiTicSUjuU.h61tiLgAWZ.CiZbXVFu', 'admin', 'https://raw.githubusercontent.com/DNAnh01/assets/main/default_user_avatar.png', '', False, 'admin', UUID('c0f80c9e-c1f4-44f8-a2a7-51eb95e753f7'), datetime.datetime(2024, 5, 12, 10, 48, 32, 377547, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 5, 12, 10, 48, 32, 377547, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), True, None)]

# %% [markdown]
# #### Test Sign In

# %%
# %sql SELECT u.email AS email, s.created_at AS session_created_at, s.expires_at AS session_expires_at, s.deleted_at AS session_deleted_at FROM users AS u LEFT JOIN sessions AS s ON u.id = s.user_id;
# Out:
#  * postgresql://postgres:***@localhost/learn-fastapi
# 27 rows affected.
# [('phuckarry634@gmail.com', datetime.datetime(2024, 4, 19, 15, 33, 54, 272410, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 19, 16, 3, 54, 272410, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None),
#  ('phuckarry634@gmail.com', datetime.datetime(2024, 4, 19, 15, 35, 22, 134203, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 19, 16, 5, 22, 134203, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None),
#  ('tranvanphuc.dev.it.2002@gmail.com', datetime.datetime(2024, 4, 19, 15, 41, 31, 258794, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 19, 16, 11, 31, 258794, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None),
#  ('phuckarry634@gmail.com', datetime.datetime(2024, 4, 19, 15, 42, 8, 207852, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 19, 16, 12, 8, 207852, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None),
#  ('phuckarry634@gmail.com', datetime.datetime(2024, 4, 19, 15, 44, 58, 861184, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 19, 16, 14, 58, 861184, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None),
#  ('phuckarry634@gmail.com', datetime.datetime(2024, 4, 19, 15, 45, 55, 86824, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 19, 16, 15, 55, 86824, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None),
#  ('phuckarry634@gmail.com', datetime.datetime(2024, 4, 19, 15, 50, 55, 429528, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 19, 16, 20, 55, 429528, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None),
#  ('phuc1234@gmail.com', datetime.datetime(2024, 4, 19, 22, 6, 1, 953432, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 19, 22, 36, 1, 953432, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None),
#  ('phuckarry634@gmail.com', datetime.datetime(2024, 4, 20, 10, 9, 9, 490656, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 20, 10, 39, 9, 490656, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None),
#  ('phuc23112@gmail.com', datetime.datetime(2024, 4, 20, 10, 10, 36, 307156, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 20, 10, 40, 36, 307156, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None),
#  ('phuc23112@gmail.com', datetime.datetime(2024, 4, 20, 10, 10, 38, 824897, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 20, 10, 40, 38, 824897, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None),
#  ('admin@admin.com', datetime.datetime(2024, 4, 28, 8, 20, 5, 488790, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 28, 8, 50, 5, 488790, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None),
#  ('phuc123@gmail.com', None, None, None),
#  ('phuc123@example.com', None, None, None),
#  ('phuc231@gmail.com', None, None, None),
#  ('phuckarry63467@gmail.com', None, None, None),
#  ('adb@gmail.com', None, None, None),
#  ('phuckarry63@gmail.com', None, None, None),
#  ('phuckarry6340@gmail.com', None, None, None),
#  ('phuckarry6345@gmail.com', None, None, None),
#  ('phuc2315@gmail.com', None, None, None),
#  ('phuckarry6341@gmail.com', None, None, None),
#  ('phuckarry631@gmail.com', None, None, None),
#  ('phuckarry6346@gmail.com', None, None, None),
#  ('phuckarry6344@gmail.com', None, None, None),
#  ('user12@example.com', None, None, None),
#  ('phuckarry634678@gmail.com', None, None, None)]

# %%
# %sql \
    SELECT \
        u.id AS u_id, \
        u.email AS u_email, \
        u.password_hash AS u_password_hash, \
        u.display_name AS u_display_name, \
        u.avatar_url AS u_avatar_url, \
        u.payment_information AS u_payment_information, \
        u.is_verified AS u_is_verified, \
        u.user_role AS u_user_role, \
        u.is_active AS u_is_active, \
        u.created_at AS u_created_at, \
        u.updated_at AS u_updated_at, \
        u.deleted_at AS u_deleted_at, \
        us.id AS us_id, \
        us.user_id AS us_user_id, \
        us.plan_id AS us_plan_id, \
        us.expire_at AS us_expire_at, \
        us.is_active AS us_is_active, \
        us.created_at AS us_created_at, \
        us.updated_at AS us_updated_at, \
        us.deleted_at AS us_deleted_at, \
        sp.id AS sp_id, \
        sp.plan_title AS sp_plan_title, \
        sp.plan_price AS sp_plan_price, \
        sp.available_model AS sp_available_model, \
        sp.message_credits AS sp_message_credits, \
        sp.number_of_chatbots AS sp_number_of_chatbots, \
        sp.max_character_per_chatbot AS sp_max_character_per_chatbot, \
        sp.live_agent_takeover AS sp_live_agent_takeover, \
        sp.remove_label AS sp_remove_label, \
        sp.is_active AS sp_is_active, \
        sp.created_at AS sp_created_at, \
        sp.updated_at AS sp_updated_at, \
        sp.deleted_at AS sp_deleted_at \
    FROM users AS u \
    LEFT JOIN user_subscriptions AS us ON u.id = us.user_id \
    LEFT JOIN subscription_plans AS sp ON us.plan_id = sp.id \
    -- WHERE u.id = 'a7e47b5d-33c1-4cde-9176-be00b6319314' \
    AND u.deleted_at IS NULL \
    AND us.deleted_at IS NULL \
    AND sp.deleted_at IS NULL;
# Out:
#  * postgresql://postgres:***@localhost/learn-fastapi
# 20 rows affected.
# [(UUID('40806ce4-e21b-4c52-abad-d23ba2ad7d0b'), 'admin@admin.com', '$2b$12$z3kGcWV3K4oQrzhsbqhhsOrn7JcIDLr.VG.4InNlrPLIi/yQWFksW', 'admin', 'https://raw.githubusercontent.com/DNAnh01/assets/main/default_user_avatar.png', '', False, 'admin', True, datetime.datetime(2024, 4, 19, 15, 32, 24, 444588, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 19, 15, 32, 24, 444588, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None, UUID('a77ff65a-02ef-43ed-91b5-66cddacb02d8'), UUID('40806ce4-e21b-4c52-abad-d23ba2ad7d0b'), UUID('f150be78-c35d-45f4-810f-cb0468e9dd0b'), datetime.datetime(2025, 4, 19, 15, 32, 24, 454166, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), True, datetime.datetime(2024, 4, 19, 15, 32, 24, 454166, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 19, 15, 32, 24, 454166, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None, UUID('f150be78-c35d-45f4-810f-cb0468e9dd0b'), 'yearly_premium', 75.0, 'GPT-4 LLM', 6000, 5, 2000000, False, False, True, datetime.datetime(2024, 4, 19, 15, 32, 24, 128786, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 19, 15, 32, 24, 128786, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None),
#  (UUID('1ef77ae5-161f-49a9-a1ea-d5a062ffc67a'), 'phuc123@example.com', '$2b$12$64gJgZEfNFN3NRmPdhQRiuXesmYZWOGstw0icXtfkymdP0Vai1wcW', 'user', 'https://raw.githubusercontent.com/DNAnh01/assets/main/default_user_avatar.png', None, False, 'user', True, datetime.datetime(2024, 4, 19, 22, 3, 41, 735834, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 19, 22, 3, 41, 735834, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None, UUID('65662d08-350f-46b2-96a2-f3ebbb679b21'), UUID('1ef77ae5-161f-49a9-a1ea-d5a062ffc67a'), UUID('79413f6e-ffec-4185-bd1f-a30e1d431752'), datetime.datetime(2024, 5, 19, 22, 3, 41, 808701, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), True, datetime.datetime(2024, 4,
), UUID('79413f6e-ffec-4185-bd1f-a30e1d431752'), datetime.datetime(2024, 5, 30, 12, 13, 53, 827667, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), True, datetime.datetime(2024, 4, 30, 12, 13, 53, 827667, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 30, 12, 13, 53, 827667, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None, UUID('79413f6e-ffec-4185-bd1f-a30e1d431752'), 'monthly_free', 0.0, 'GPT-3.5-Turbo LLM', 30, 1, 200000, False, False, True, datetime.datetime(2024, 4, 19, 15, 32, 24, 113161, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 19, 15, 32, 24, 113161, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None),
#  (UUID('4f7ad2a4-08d7-4cb7-9f86-a59f63a9df88'), 'phuc2315@gmail.com', '$2b$12$PBNqfh9TVG3h9EbrdrP0cO66cHUXaskIlMW/PEv4NEEAKRoSWWbtS', 'user', 'https://raw.githubusercontent.com/DNAnh01/assets/main/default_user_avatar.png', None, False, 'user', True, datetime.datetime(2024, 4, 30, 15, 39, 36, 764693, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 30, 15, 39, 36, 764693, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None, UUID('26bba647-ebdd-4181-b673-d9e68549b5c8'), UUID('4f7ad2a4-08d7-4cb7-9f86-a59f63a9df88'), UUID('79413f6e-ffec-4185-bd1f-a30e1d431752'), datetime.datetime(2024, 5, 30, 15, 39, 36, 776885, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), True, datetime.datetime(2024, 4, 30, 15, 39, 36, 776885, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 30, 15, 39, 36, 776885, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None, UUID('79413f6e-ffec-4185-bd1f-a30e1d431752'), 'monthly_free', 0.0, 'GPT-3.5-Turbo LLM', 30, 1, 200000, False, False, True, datetime.datetime(2024, 4, 19, 15, 32, 24, 113161, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 19, 15, 32, 24, 113161, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None),
#  (UUID('492c4759-a9b7-4317-9226-3a1ba83864f4'), 'phuckarry631@gmail.com', '$2b$12$EgcQg/9xTFPZEqLV2cBRnelfrh/B2Kf.OCFJsrVGYPIp.wJsutM.K', 'user', 'https://raw.githubusercontent.com/DNAnh01/assets/main/default_user_avatar.png', None, False, 'user', True, datetime.datetime(2024, 4, 30, 15, 53, 17, 119632, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 30, 15, 53, 17, 119632, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None, UUID('711ac001-7e38-4272-88ba-1d513080c938'), UUID('492c4759-a9b7-4317-9226-3a1ba83864f4'), UUID('79413f6e-ffec-4185-bd1f-a30e1d431752'), datetime.datetime(2024, 5, 30, 15, 53, 17, 135121, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), True, datetime.datetime(2024, 4, 30, 15, 53, 17, 135121, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 30, 15, 53, 17, 135121, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None, UUID('79413f6e-ffec-4185-bd1f-a30e1d431752'), 'monthly_free', 0.0, 'GPT-3.5-Turbo LLM', 30, 1, 200000, False, False, True, datetime.datetime(2024, 4, 19, 15, 32, 24, 113161, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 19, 15, 32, 24, 113161, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None),
#  (UUID('d85c66e2-ab0f-4d48-8012-29af8bbbe907'), 'phuc123@gmail.com', '$2b$12$3.8KABwNqTK1K5hsg01CK.hotwC0e7LA4OhDTQhFM5oMjz.E3il.m', 'user', 'https://raw.githubusercontent.com/DNAnh01/assets/main/default_user_avatar.png', None, False, 'user', True, datetime.datetime(2024, 5, 4, 7, 11, 32, 149484, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 5, 4, 7, 11, 32, 149484, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None, UUID('56e073bb-fefa-40e2-bfae-426fe9ca11c5'), UUID('d85c66e2-ab0f-4d48-8012-29af8bbbe907'), UUID('79413f6e-ffec-4185-bd1f-a30e1d431752'), datetime.datetime(2024, 6, 3, 7, 11, 32, 222423, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), True, datetime.datetime(2024, 5, 4, 7, 11, 32, 222423, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 5, 4, 7, 11, 32, 222423, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None, UUID('79413f6e-ffec-4185-bd1f-a30e1d431752'), 'monthly_free', 0.0, 'GPT-3.5-Turbo LLM', 30, 1, 200000, False, False, True, datetime.datetime(2024, 4, 19, 15, 32, 24, 113161, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 19, 15, 32, 24, 113161, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None),
#  (UUID('f92c3d93-3788-41c2-991b-eceb018f9ad8'), 'phuckarry634@gmail.com', 'arUoXaRiMWrV_nqz9zskOQ', 'Phúc Trần', 'https://lh3.googleusercontent.com/a/ACg8ocKpmmQwE7-OOw6FeHY4bF0AZCXuyK3JivAUFX5zMwNq3rrReY8i=s96-c', None, False, 'user', True, datetime.datetime(2024, 4, 19, 15, 33, 54, 256020, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 19, 15, 33, 54, 256020, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  (UUID('0927c273-f671-4491-a00f-ec7b92a69fee'), 'tranvanphuc.dev.it.2002@gmail.com', 'GHEm7vc6SJ42VT7jMIQnZQ', 'Phúc Trần Văn', 'https://lh3.googleusercontent.com/a/ACg8ocKmEFmGJ1dMYswwcoGmR8zaLOMJgnAb4sDjK451OpwDARKf8kc=s96-c', None, False, 'user', True, datetime.datetime(2024, 4, 19, 15, 41, 31, 239715, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), datetime.datetime(2024, 4, 19, 15, 41, 31, 239715, tzinfo=datetime.timezone(datetime.timedelta(seconds=25200))), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None)]
